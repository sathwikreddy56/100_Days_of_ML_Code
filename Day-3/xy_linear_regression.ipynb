# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('../DATASETS/Linear Regression/xy cordinate /train.csv')
test = pd.read_csv('../DATASETS/Linear Regression/xy cordinate /test.csv')
train.head()
# Out:
#     x          y
# 0  24  21.549452
# 1  50  47.464463
# 2  15  17.218656
# 3  38  36.586398
# 4  87  87.288984

# %%
# plt.scatter(train['x'],train['y'])
train['x'].shape
train['y'].shape
# Out:
# (699,)

# %%
from sklearn.linear_model import LinearRegression
linear_reg=LinearRegression()
X = np.array(data['x']).reshape((-1, 1))
test_x = np.array(test['x']).reshape((-1, 1))
linear_reg.fit(X,train['y'])
#predicting the datset values
y_pred = linear_reg.predict(test_x)

# %%
from sklearn.metrics import mean_squared_error 
mse = mean_squared_error(test['y'], y_pred) 
print("Mean Square Error : ", mse)
# Out:
# Mean Square Error :  9.432922192039305

# %%
plt.scatter(test['y'], y_pred)
